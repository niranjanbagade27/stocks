# %%
import pandas as pd
import os
import shutil

# --- Configuration ---
# Define the names of the input and output folders.
# These folders are assumed to be in the same directory as this script.
input_folder_name = '10YearClubbedData'
output_folder_name = 'weeklystats'

# Get the path to the current working directory
base_path = os.getcwd()

# Construct the full paths for the input and output folders
input_folder_path = os.path.join(base_path, input_folder_name)
output_folder_path = os.path.join(base_path, output_folder_name)

# --- Main Script ---

# Check if the input folder exists
if not os.path.exists(input_folder_path):
    print(f"Error: The input folder '{input_folder_path}' was not found. Please ensure it exists.")
else:
    # Delete the output folder if it exists, to ensure a clean run.
    if os.path.exists(output_folder_path):
        shutil.rmtree(output_folder_path)
        print(f"Deleted existing output folder: {output_folder_path}")
        
    # Create the new output folder
    os.makedirs(output_folder_path)
    print(f"Created new output folder: {output_folder_path}")

    # Get a list of all CSV files in the input folder
    combined_files = [f for f in os.listdir(input_folder_path) if f.endswith('.csv') and not f.startswith('.')]

    if not combined_files:
        print(f"No CSV files found in the '{input_folder_name}' folder. Nothing to process.")
    else:
        # Loop through each combined file
        for file_name in combined_files:
            print(f"\n--- Processing file: {file_name} ---")
            
            # Construct the full path to the current file
            file_path = os.path.join(input_folder_path, file_name)

            try:
                # Read the combined daily data into a pandas DataFrame.
                combined_df = pd.read_csv(file_path, thousands=',')
                
                # Ensure the 'Date' column is in datetime format and set it as the index
                combined_df['Date'] = pd.to_datetime(combined_df['Date'])
                combined_df.set_index('Date', inplace=True)
                
                # Define the aggregation logic for each column for weekly resampling
                weekly_aggregation = {
                    'Open Price': 'first',
                    'High Price': 'max',
                    'Low Price': 'min',
                    'Close Price': 'last',
                    'Total Traded Quantity': 'sum',
                    'Turnover ₹': 'sum',
                    'No. of Trades': 'sum',
                    'Deliverable Qty': 'sum',
                    'Last Price': 'last',
                    'Average Price': 'mean'
                }
                
                # Resample the data to a weekly frequency ('W-MON') and apply the aggregations
                # This explicitly sets the week to start on Monday.
                weekly_df = combined_df.resample('W-MON').agg(weekly_aggregation)
                
                # For simplicity, we'll fill the constant columns like 'Symbol' and 'Series'
                # with the first available value from the daily data.
                if 'Symbol' in combined_df.columns:
                    weekly_df['Symbol'] = combined_df['Symbol'].iloc[0]
                if 'Series' in combined_df.columns:
                    weekly_df['Series'] = combined_df['Series'].iloc[0]
                
                # Reset the index to make 'Date' a column again before saving
                weekly_df.reset_index(inplace=True)

                # Create a new output file name (e.g., 'Bajaj-Combined-Weekly-Data.csv')
                output_file_name = file_name.replace('-Data.csv', '-Weekly-Data.csv')
                output_file_path = os.path.join(output_folder_path, output_file_name)
                
                # Save the new weekly data to a CSV file
                weekly_df.to_csv(output_file_path, index=False)
                
                print(f"Successfully converted '{file_name}' to weekly data and saved as '{output_file_name}'.")
                print(f"Total rows in new weekly file: {len(weekly_df)}")
                
            except Exception as e:
                print(f"An error occurred while processing {file_name}: {e}")

print("\n--- All files have been processed ---")
# Out:
# Deleted existing output folder: /Users/niranjansmacbook/PycharmProjects/DBA/DBA-Capstone/Stocks/RawData/weeklystats
# Created new output folder: /Users/niranjansmacbook/PycharmProjects/DBA/DBA-Capstone/Stocks/RawData/weeklystats
#
# --- Processing file: EICHERMOT-Combined-Data.csv ---
# Successfully converted 'EICHERMOT-Combined-Data.csv' to weekly data and saved as 'EICHERMOT-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: HDFCBANK-Combined-Data.csv ---
# Successfully converted 'HDFCBANK-Combined-Data.csv' to weekly data and saved as 'HDFCBANK-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: TATAMOTORS-Combined-Data.csv ---
# Successfully converted 'TATAMOTORS-Combined-Data.csv' to weekly data and saved as 'TATAMOTORS-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: SUNPHARMA-Combined-Data.csv ---
# Successfully converted 'SUNPHARMA-Combined-Data.csv' to weekly data and saved as 'SUNPHARMA-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: BAJAJFINSV-Combined-Data.csv ---
# Successfully converted 'BAJAJFINSV-Combined-Data.csv' to weekly data and saved as 'BAJAJFINSV-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: TITAN-Combined-Data.csv ---
# Successfully converted 'TITAN-Combined-Data.csv' to weekly data and saved as 'TITAN-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: POWERGRID-Combined-Data.csv ---
# Successfully converted 'POWERGRID-Combined-Data.csv' to weekly data and saved as 'POWERGRID-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: TATASTEEL-Combined-Data.csv ---
# Successfully converted 'TATASTEEL-Combined-Data.csv' to weekly data and saved as 'TATASTEEL-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: ICICIBANK-Combined-Data.csv ---
# Successfully converted 'ICICIBANK-Combined-Data.csv' to weekly data and saved as 'ICICIBANK-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: WIPRO-Combined-Data.csv ---
# Successfully converted 'WIPRO-Combined-Data.csv' to weekly data and saved as 'WIPRO-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: TECHM-Combined-Data.csv ---
# Successfully converted 'TECHM-Combined-Data.csv' to weekly data and saved as 'TECHM-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: MARUTI-Combined-Data.csv ---
# Successfully converted 'MARUTI-Combined-Data.csv' to weekly data and saved as 'MARUTI-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: ASIANPAINT-Combined-Data.csv ---
# Successfully converted 'ASIANPAINT-Combined-Data.csv' to weekly data and saved as 'ASIANPAINT-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: BPCL-Combined-Data.csv ---
# Successfully converted 'BPCL-Combined-Data.csv' to weekly data and saved as 'BPCL-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: RELIANCE-Combined-Data.csv ---
# Successfully converted 'RELIANCE-Combined-Data.csv' to weekly data and saved as 'RELIANCE-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: ITC-Combined-Data.csv ---
# Successfully converted 'ITC-Combined-Data.csv' to weekly data and saved as 'ITC-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: HINDUNILVR-Combined-Data.csv ---
# Successfully converted 'HINDUNILVR-Combined-Data.csv' to weekly data and saved as 'HINDUNILVR-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: MM-Combined-Data.csv ---
# Successfully converted 'MM-Combined-Data.csv' to weekly data and saved as 'MM-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: GRASIM-Combined-Data.csv ---
# Successfully converted 'GRASIM-Combined-Data.csv' to weekly data and saved as 'GRASIM-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: KOTAKBANK-Combined-Data.csv ---
# Successfully converted 'KOTAKBANK-Combined-Data.csv' to weekly data and saved as 'KOTAKBANK-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: AXISBANK-Combined-Data.csv ---
# Successfully converted 'AXISBANK-Combined-Data.csv' to weekly data and saved as 'AXISBANK-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: ADANIPORTS-Combined-Data.csv ---
# Successfully converted 'ADANIPORTS-Combined-Data.csv' to weekly data and saved as 'ADANIPORTS-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: TCS-Combined-Data.csv ---
# Successfully converted 'TCS-Combined-Data.csv' to weekly data and saved as 'TCS-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: BHARTIARTL-Combined-Data.csv ---
# Successfully converted 'BHARTIARTL-Combined-Data.csv' to weekly data and saved as 'BHARTIARTL-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: INFY-Combined-Data.csv ---
# Successfully converted 'INFY-Combined-Data.csv' to weekly data and saved as 'INFY-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: SBIN-Combined-Data.csv ---
# Successfully converted 'SBIN-Combined-Data.csv' to weekly data and saved as 'SBIN-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: NTPC-Combined-Data.csv ---
# Successfully converted 'NTPC-Combined-Data.csv' to weekly data and saved as 'NTPC-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: BAJFINANCE-Combined-Data.csv ---
# Successfully converted 'BAJFINANCE-Combined-Data.csv' to weekly data and saved as 'BAJFINANCE-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: SHRIRAMFIN-Combined-Data.csv ---
# Successfully converted 'SHRIRAMFIN-Combined-Data.csv' to weekly data and saved as 'SHRIRAMFIN-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: APOLLOHOSP-Combined-Data.csv ---
# Successfully converted 'APOLLOHOSP-Combined-Data.csv' to weekly data and saved as 'APOLLOHOSP-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: DRREDDY-Combined-Data.csv ---
# Successfully converted 'DRREDDY-Combined-Data.csv' to weekly data and saved as 'DRREDDY-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: TATACONSUM-Combined-Data.csv ---
# Successfully converted 'TATACONSUM-Combined-Data.csv' to weekly data and saved as 'TATACONSUM-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: COALINDIA-Combined-Data.csv ---
# Successfully converted 'COALINDIA-Combined-Data.csv' to weekly data and saved as 'COALINDIA-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: ONGC-Combined-Data.csv ---
# Successfully converted 'ONGC-Combined-Data.csv' to weekly data and saved as 'ONGC-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: HINDALCO-Combined-Data.csv ---
# Successfully converted 'HINDALCO-Combined-Data.csv' to weekly data and saved as 'HINDALCO-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: NESTLEIND-Combined-Data.csv ---
# Successfully converted 'NESTLEIND-Combined-Data.csv' to weekly data and saved as 'NESTLEIND-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: INDUSINDBK-Combined-Data.csv ---
# Successfully converted 'INDUSINDBK-Combined-Data.csv' to weekly data and saved as 'INDUSINDBK-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: BAJAJ-AUTO-Combined-Data.csv ---
# Successfully converted 'BAJAJ-AUTO-Combined-Data.csv' to weekly data and saved as 'BAJAJ-AUTO-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: JSWSTEEL-Combined-Data.csv ---
# Successfully converted 'JSWSTEEL-Combined-Data.csv' to weekly data and saved as 'JSWSTEEL-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: LT-Combined-Data.csv ---
# Successfully converted 'LT-Combined-Data.csv' to weekly data and saved as 'LT-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: BEL-Combined-Data.csv ---
# Successfully converted 'BEL-Combined-Data.csv' to weekly data and saved as 'BEL-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: HEROMOTOCO-Combined-Data.csv ---
# Successfully converted 'HEROMOTOCO-Combined-Data.csv' to weekly data and saved as 'HEROMOTOCO-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: ADANIENT-Combined-Data.csv ---
# Successfully converted 'ADANIENT-Combined-Data.csv' to weekly data and saved as 'ADANIENT-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: HCLTECH-Combined-Data.csv ---
# Successfully converted 'HCLTECH-Combined-Data.csv' to weekly data and saved as 'HCLTECH-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: ULTRACEMCO-Combined-Data.csv ---
# Successfully converted 'ULTRACEMCO-Combined-Data.csv' to weekly data and saved as 'ULTRACEMCO-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: TRENT-Combined-Data.csv ---
# Successfully converted 'TRENT-Combined-Data.csv' to weekly data and saved as 'TRENT-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- Processing file: CIPLA-Combined-Data.csv ---
# Successfully converted 'CIPLA-Combined-Data.csv' to weekly data and saved as 'CIPLA-Combined-Weekly-Data.csv'.
# Total rows in new weekly file: 575
#
# --- All files have been processed ---
